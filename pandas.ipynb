# %%
import numpy as np
import pandas as pd

temp = pd.Series([18, 22, 31, 27])

temp.index = ("Mon", "Tue", "Wed", "Thu")

print("Temperature data:")
print(temp)

print("Wednesday temperature:", temp["Wed"])

print("Total of all temperatures:", temp.sum())
# Out:
# Temperature data:
# Mon    18
# Tue    22
# Wed    31
# Thu    27
# dtype: int64
# Wednesday temperature: 31
# Total of all temperatures: 98
